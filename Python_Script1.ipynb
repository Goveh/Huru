# %%
# Work with scalar, vectors and matrices in Python using numpy
import numpy as np

# %%
s = 5.2

# %%
print(s)
# Out:
# 5.2

# %%
# Declare a vector
v = np.array([5,-2,4])

# %%
print(v)
# Out:
# [ 5 -2  4]

# %%
# Declare a matrix
m = np.array([[5,12,6],[-3,0,14]])

# %%
print(m)
# Out:
# [[ 5 12  6]
#  [-3  0 14]]

# %%
type(s)
# Out:
# float

# %%
type(m)
# Out:
# numpy.ndarray

# %%
type(v)
# Out:
# numpy.ndarray

# %%
# To return the shape or dimension of the matrix m
m.shape
# Out:
# (2, 3)

# %%
# To return the shape or dimension of the vector v
v.shape
# Out:
# (3,)

# %%
print(m)
# Out:
# [[ 5 12  6]
#  [-3  0 14]]

# %%
m
# Out:
# array([[ 5, 12,  6],
#        [-3,  0, 14]])

# %%
m1 = np.array([[9,8,7],[1,3,-5]])

# %%
m1
# Out:
# array([[ 9,  8,  7],
#        [ 1,  3, -5]])

# %%
#Define Matrix t using the matrices m and m1
t=np.array([m,m1])

# %%
t
# Out:
# array([[[ 5, 12,  6],
#         [-3,  0, 14]],
#
#        [[ 9,  8,  7],
#         [ 1,  3, -5]]])

# %%
# Display the shape of matrix t
t.shape
# Out:
# (2, 2, 3)

# %%
# Adding matrices
m2 = m + m1

# %%
m2
# Out:
# array([[14, 20, 13],
#        [-2,  3,  9]])

# %%
# Subtracting the matrices
m2 = m - m

# %%
m2
# Out:
# array([[-4,  4, -1],
#        [-4, -3, 19]])

# %%
v1 = np.array([1,2,3,4,5])
v2 = np.array([5,4,3,2,1])

# %%
print(v1+v2)
# Out:
# [6 6 6 6 6]

# %%
v1-v2
# Out:
# array([-4, -2,  0,  2,  4])

# %%
# Transposong in quality
# Changed 0to Fo
m2.transpose
# Out:
# <function ndarray.transpose>

# %%
  m2.T
# Out:
# array([[-4, -4],
#        [ 4, -3],
#        [-1, 19]])

# %%
# Create vector 
v3 = np.array([2,8,-4])

# %%
v3
# Out:
# array([ 2,  8, -4])

# %%
v3.shape
# Out:
# (3,)

# %%
v4  = np.array([1,-7,3])

# %%
v4
# Out:
# array([ 1, -7,  3])

# %%
v3 * v4
# Out:
# array([  2, -56,  12])

# %%
# The dot product for vectors v3 & v4
np.dot(v3,v4)
# Out:
# -66

# %%
# Create the vector
r = np.array([0,2,5,8])
s = np.array([20,3,4,-1])

# %%
np.dot(r,s)
# Out:
# 18

# %%
v3
# Out:
# array([ 2,  8, -4])

# %%
# Multiply a scalar by the given array
5*v3
# Out:
# array([ 10,  40, -20])
