# %% [markdown]
# <a href="https://colab.research.google.com/github/Goveh/Huru_DSC_Class/blob/main/covid_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('owid_covid_data.csv')

# %%
print(df)

# %%
df.shape
# Out:
# (26435, 59)

# %%
df.tail(5) # Display bottom 5 items

# %%
df.head(5)  # Display top 5 items
# Out:
#   iso_code continent  ... life_expectancy human_development_index
# 0      AFG      Asia  ...           64.83                   0.511
# 1      AFG      Asia  ...           64.83                   0.511
# 2      AFG      Asia  ...           64.83                   0.511
# 3      AFG      Asia  ...           64.83                   0.511
# 4      AFG      Asia  ...           64.83                   0.511
#
# [5 rows x 59 columns]

# %%
df.dtypes  # Values data types

# %%
df[['location','total_cases']]

# %%
summary = df.groupby ('continent')

# %%
summary.describe()
# Out:
#               total_cases                              ... human_development_index
#                     count          mean           std  ...                     50%    75%    max
# continent                                              ...
# Africa             7953.0  1.734820e+04  3.575122e+04  ...                   0.554  0.611  0.748
# Asia               3782.0  7.438029e+04  1.237449e+05  ...                   0.756  0.776  0.852
# Europe             4990.0  1.176595e+05  2.302303e+05  ...                   0.887  0.922  0.940
# North America      4045.0  6.014400e+04  1.523028e+05  ...                   0.783  0.814  0.929
# Oceania             843.0  9.735601e+03  1.231449e+04  ...                   0.944  0.944  0.944
# South America      2472.0  1.239768e+06  2.410863e+06  ...                   0.767  0.845  0.851
#
# [6 rows x 432 columns]
